# %% [markdown]
# # **python interview question**

# %%
#square of 10 numbers
square = []
for i in range(1,11):
  square.append(i**2)
print(square)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
#comprehension
square = [i**2 for i in range(1,11) ]

# %%
square
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
movie = [("Iron man1",2008),("Spiderman",2011),("Endgame",2019),("Avengers",2012),]

# %%
#tuple comprehension
movielist = [title for title,years in movie if years>2010]

# %%
movielist
# Out:
# ['Spiderman', 'Endgame', 'Avengers']

# %%
movielist=[x for x,i in movie if i > 2010]
movielist
# Out:
# ['Spiderman', 'Endgame', 'Avengers']

# %%
#list to string
list1=["hi ","this ","Faisal"]
string1=''.join(list1)
string1
# Out:
# 'hi this Faisal'

# %%
#list to tuple
list1=['hi','this','Faisal']
tup1=tuple(list1)
tup1
# Out:
# ('hi', 'this', 'Faisal')

# %%
#list to set
list1=['hi','this','Faisal']
set1=set(list1)
set1
# Out:
# {'Faisal', 'hi', 'this'}

# %%
#set to list
set1={'hi','this','Faisal'}
list2=list(set1)
list2
# Out:
# ['hi', 'this', 'Faisal']

# %%
#remove duplicate value from list
list1=['hi','this','Faisal','Faisal']
list1
# Out:
# ['hi', 'this', 'Faisal', 'Faisal']

# %%
#step-1:list to set
set1=set(list1)
set1
# Out:
# {'Faisal', 'hi', 'this'}

# %%
#step-2:set to list
list1=list(set1)
list1
# Out:
# ['hi', 'Faisal', 'this']

# %%
#count occurance
list1
# Out:
# ['hi', 'Faisal', 'this']

# %%
list1.count("Faisal")
# Out:
# 1

# %%
list1.count("hi")
# Out:
# 1

# %%
#add element in a list
list1
# Out:
# ['hi', 'Faisal', 'this']

# %%
list1.append("Uddin")

# %%
list1
# Out:
# ['hi', 'Faisal', 'this', 'Uddin']

# %%
#concatenate two lists
list1=['hi','this','Faisal']
list2=['Md']
list1.extend(list2)

# %%
list1
# Out:
# ['hi', 'this', 'Faisal', 'Faisal', 'Md']

# %%
list1=['hi','this','Faisal']
list2=[1,2,3,4]

# %%
list1.append(list2)

# %%
list1
# Out:
# ['hi', 'this', 'Faisal', [1, 2, 3, 4]]

# %%
list1=['hi','this','Faisal']
list2=[1,2,3,4]
list1.extend(list2)
list1
# Out:
# ['hi', 'this', 'Faisal', 1, 2, 3, 4]

# %%
list1=['hi','this','Faisal']
list2=[1,2,3,4]
list3=list1+list2
list3
# Out:
# ['hi', 'this', 'Faisal', 1, 2, 3, 4]

# %%
#username and domain seperation
email="ghostfireknight84@gmail.com"

# %%
email.split('@')
# Out:
# ['ghostfireknight84', 'gmail.com']

# %%
username,domain=email.split('@')

# %%
username
# Out:
# 'ghostfireknight84'

# %%
domain
# Out:
# 'gmail.com'

# %%
def test(a):
  return len(a)

# %%
test("Faisal")
# Out:
# 6

# %%
#map function
#variable=map(function,(iterables))
x=map(test,("Md" , "Faisal", "Uddin"))
# list(x)

# %%
list(x)
# Out:
# [2, 6, 5]

# %%
def test2(a,b):
  return a+b

# %%
y=map(test2,("apple","banana"),("cherry","pineapple"))

# %%
list(y)
# Out:
# ['applecherry', 'bananapineapple']

# %%
def myfunc(n):
  return len(n)

# %%
myfunc("Gmail")
# Out:
# 5

# %%
myfunc("Bugatti")
# Out:
# 7

# %%
#map
x=map(myfunc, ('apple','banana','cherry'))

# %%
list(x)
# Out:
# [5, 6, 6]

# %%
def myfunc(a,b):
  return a+b

# %%
x=map(myfunc, ('apple','banana','cherry'),('orange','lemon','pineaapple'))

# %%
list(x)
# Out:
# ['appleorange', 'bananalemon', 'cherrypineaapple']

# %%
def addition(n):
  return n+n

# %%
num=(1,2,3,4,5)

# %%
result=map(addition,(num))

# %%
list(result)
# Out:
# [2, 4, 6, 8, 10]
