# %%
l1=[1,2,3,4,5]

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l1[0] = 'data science' #replacing index

# %%
l1
# Out:
# ['data science', 2, 3, 4, 5]

# %%
l1[-1] = 'Faisal'

# %%
l1
# Out:
# ['data science', 2, 3, 4, 'Faisal']

# %%
l1.append('Dataquest') #adding something

# %%
l1
# Out:
# ['data science', 2, 3, 4, 'Faisal', 'Dataquest']

# %%
l1.append('Faisal') #exist same type of value in the list

# %%
l1
# Out:
# ['data science', 2, 3, 4, 'Faisal', 'Dataquest', 'Faisal']

# %%
l1.append(5)

# %%
l1
# Out:
# ['data science', 2, 3, 4, 'Faisal', 'Dataquest', 'Faisal', 5]

# %%
a = ["apple", "banana", "cherry"]

b = ["Ford", "BMW", "Volvo"]

a.append(b)

# %%
a
# Out:
# ['apple', 'banana', 'cherry', ['Ford', 'BMW', 'Volvo']]

# %%
l1
# Out:
# ['data science', 2, 3, 4, 'Faisal', 'Dataquest', 'Faisal', 5]

# %%
#sys module provide  functions and variables
#let us access system specific parameter and functions
import sys
sys.getsizeof(l1) #size of the memory
# Out:
# 144

# %%
sys.getsizeof(a)
# Out:
# 128

# %%
l1.pop()
# Out:
# 5

# %%
l1
# Out:
# ['data science', 2, 3, 4, 'Faisal', 'Dataquest', 'Faisal']

# %%
l1.pop()
# Out:
# 'Faisal'

# %%
l1
# Out:
# ['data science', 2, 3, 4, 'Faisal', 'Dataquest']

# %%
l1.pop(0)
# Out:
# 'data science'

# %%
l1
# Out:
# [2, 3, 4, 'Faisal', 'Dataquest']

# %%
#list using constructor

# %%
l2 = list((1,2,3,4,5)) #list function

# %%
l2
# Out:
# [1, 2, 3, 4, 5]

# %%
l2 = list((1,2,3,4,5,'data science',(1,2,3,4,5)))

# %%
l2
# Out:
# [1, 2, 3, 4, 5, 'data science', (1, 2, 3, 4, 5)]

# %%
type(l2)
# Out:
# list

# %%
len(l2)
# Out:
# 7

# %%
l2[0]
# Out:
# 1

# %%
l2[-1]
# Out:
# (1, 2, 3, 4, 5)
