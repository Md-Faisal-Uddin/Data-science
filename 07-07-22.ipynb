# %% [markdown]
# **class:12-python dara structer**

# %%
l1 = [1,2,3,4,5]

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
type(l1)
# Out:
# list

# %%
len(l1)
# Out:
# 5

# %%
# list is ordered
l1[0]
# Out:
# 1

# %%
l1[2]
# Out:
# 3

# %%
l1[-1]
# Out:
# 5

# %%
l1[0:2]
# Out:
# [1, 2]

# %%
#l1 = [1,2,3,4,5]
l1[0:3]
# Out:
# [1, 2, 3]

# %%
l1[0] =
